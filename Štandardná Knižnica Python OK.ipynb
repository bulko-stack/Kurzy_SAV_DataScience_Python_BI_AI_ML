# %% [markdown]
# # Prehľad Modulov

# %% [markdown]
# # 🐍 Kurz Štandardná Knižnica Python
# **🧑‍🏫 Lektor:** Miroslav Reiter
# **📥 LinkedIn kontakt:** https://www.linkedin.com/in/miroslav-reiter/
#
# **✅ Osnova:** https://eurocc.nscc.sk/it-kurzy/
# 1. Prehľad modulov štandardnej Python knižnice
# 2. Práca s dátami a súbormi (os, pathlib, csv, json)
# 3. Práca s časom a generovanie dát (datetime, random)
# 4. Efektívna práca s dátovými štruktúrami (collections)
# 5. Logovanie a diagnostika (logging, sys)
#
# **🎞️ YouTube videá:** https://www.youtube.com/@VITA-Academy
# **📇 Zdrojové kódy a materiály:** https://github.com/miroslav-reiter/Kurzy_DataScience_Python_BI_AI_ML/tree/main
#
# **😊 Emojis:** Win + .

# %% [markdown]
# ## ⚒️ Používané nástroje Python
# - 🐍 **Python** - momentálne najpopulárnejší jazyk pre vedu o údajoch (Data science). Python je síce interpretovaný a pomalší jazyk ako C/C++, ale využitím knižníc, ako je NumPy (a Pandas navyše), sa môžeme priblížiť rýchlosti C.
#
# - 🪐 **Jupyter** - nástroj s prostredím interaktívneho notebooku, mocný prieskumný, vizualizačný a komunikačný nástroj.
#
# - 📚 **Štandardná Python knižnica** - knižnica, ktorá obsahuje množstvo základných modulov pre prácu so súbormi, časom, systémovými operáciami, manipuláciou s reťazcami a mnohé ďalšie funkcie.
#
# 1. os - poskytuje rozhranie na interakciu s operačným systémom.
# 2. pathlib - ponúka objektovo orientovaný spôsob práce s cestami k súborom.
# 3. csv - umožňuje čítanie a zápis CSV súborov.
# 4. json - umožňuje prácu s JSON formátom na ukladanie a načítavanie dát.
# 5. datetime - pre prácu s dátumami a časom.
# 6. random - generovanie náhodných čísel a výberov.
# 7. collections - poskytuje ďalšie štruktúry dát, ako sú namedtuple, deque alebo Counter, ktoré zjednodušujú manipuláciu s údajmi.
# 8. logging - nástroj na logovanie informácií v aplikáciách.
# 9. sys - umožňuje prácu so systémovými parametrami a vstupmi/výstupmi.
#
#
# 😎 Existuje 300 000+ knižníc pre Python.

# %% [markdown]
# ## 1️⃣ Prehľad modulov štandardnej Python knižnice
# **📌 Úloha:** Zobraziť zoznam všetkých dostupných modulov. Zobraziť všetky moduly, ktoré sú súčasťou štandardnej Python knižnice.

# %%
help("modules")

# Pri spustení príkazu help("modules") sa zobrazili varovania týkajúce sa niektorých knižníc a ich deprecácie. Tento výstup sa netýka priamo štandardnej Python knižnice, ale skôr externých knižníc a ich stavov. Tieto varovania sa môžu objaviť v prostredí, kde sú nainštalované rôzne balíky, ako napríklad torch alebo numpy, ktoré môžu obsahovať deprecated funkcie alebo submoduly.
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
# Python version: 3.8.20 (default, Mar  4 2025, 17:24:18)  [GCC 11.4.0]
# GEOS version: 3.11.4-CAPI-1.17.4
# Numpy version: 1.24.4
# IPython             catalogue           language_data       send2trash
# PIL                 certifi             lazy_loader         setuptools
# __future__          cffi                lets_plot           shapely
# _abc                cgi                 lets_plot_kotlin_bridge shellingham
# _argon2_cffi_bindings cgitb               lib2to3             shelve
# _ast                charset_normalizer  linecache           shlex
# _asyncio            chunk               locale              shutil
# _bisect             clang               logging             signal
# _blake2             click               lxml                site
# ...

# %%
# Ako získať zoznam všetkých nahraných modulov v aktuálnom Python prostredí.

import sys

# Zobraziť zoznam všetkých nahraných modulov
print("Nahrané moduly:")
for mod in sys.modules:
    print(mod)
# Out:
# Nahrané moduly:
# sys
# builtins
# _frozen_importlib
# _imp
# _warnings
# _io
# marshal
# posix
# _frozen_importlib_external
# _thread
# _weakref
# time
# zipimport
# _codecs
# codecs
# encodings.aliases
# encodings
# encodings.utf_8
# _signal
# __main__
# encodings.latin_1
# _abc
# abc
# io
# _stat
# stat
# _collections_abc
# genericpath
# posixpath
# os.path
# os
# _sitebuiltins
# _locale
# _bootlocale
# _distutils_hack
# types
# importlib._bootstrap
# importlib._bootstrap_external
# warnings
# importlib
# importlib.machinery
# importlib.abc
# _operator
# operator
# keyword
# _heapq
# heapq
# itertools
# reprlib
# _collections
# collections
# _functools
# functools
# contextlib
# importlib.util
# mpl_toolkits
# google
# sphinxcontrib
# site
# _weakrefset
# weakref
# pkgutil
# runpy
# ipykernel._version
# enum
# _sre
# sre_constants
# sre_parse
# sre_compile
# copyreg
# re
# _json
# json.scanner
# json.decoder
# json.encoder
# json
# errno
# signal
# threading
# _posixsubprocess
# ...

# %%
# Zobrazenie zoznamu štandardných Python modulov bez týchto varovaní

# pkgutil: Tento modul je súčasťou Pythonu a poskytuje funkcie na prácu s balíkmi a modulmi. Pomáha v navigovaní a inšpekcii nainštalovaných balíkov.

# sys: Tento modul poskytuje prístup k niektorým premenným a funkciám, ktoré ovládajú prostredie Pythonu, ako sú argumenty príkazového riadku, systémové cesty a ďalšie.

import pkgutil
import sys

# Vytvoriť zoznam všetkých dostupných modulov
modules = [module.name for module in pkgutil.iter_modules()]
print(f"Pocet modulov: {len(modules)}") 

print(f"Zoznam modulov: {modules}")
# Out:
# Pocet modulov: 524
# ...

# %%
import sys
# import builtins

# Zobraziť vstavané moduly v Pythonu
builtin_modules = sys.builtin_module_names

print(f"Pocet zabudovaných modulov: {len(builtin_modules)}") 

print(f"Zoznam zabudovaných modulov: {builtin_modules}")
# Out:
# Pocet zabudovaných modulov: 30
# Zoznam zabudovaných modulov: ('_abc', '_ast', '_codecs', '_collections', '_functools', '_imp', '_io', '_locale', '_operator', '_signal', '_sre', '_stat', '_string', '_symtable', '_thread', '_tracemalloc', '_warnings', '_weakref', 'atexit', 'builtins', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'posix', 'pwd', 'sys', 'time', 'xxsubtype')

# %% [markdown]
# 📌 Úloha: Skontrolovať, či modul math existuje v štandardnej knižnici

# %%
import sys
print("time" in sys.builtin_module_names)  # True/False
# Out:
# True

# %%
import os
import sys
import importlib.util

# Funkcia na načítanie štandardných knižníc
def get_standard_modules():
    # Získanie cesty k štandardnej knižnici Pythonu
    standard_lib = os.path.join(sys.prefix, 'lib', f'python{sys.version_info[0]}.{sys.version_info[1]}', 'site-packages')

    modules = []
    # Prehľadávanie knižníc v štandardnej knižnici
    for root, dirs, files in os.walk(standard_lib):
        for file in files:
            if file.endswith(".py"):  # Kontrola súborov s príponou .py
                module_name = file[:-3]  # Odstránenie prípony .py
                modules.append(module_name)
    return modules

# Získanie zoznamu štandardných modulov
modules = get_standard_modules()

print(f"Pocet modulov: {len(modules)}") 

print(f"Zoznam modulov: {modules}")
# Out:
# Pocet modulov: 38152
# ...

# %% [markdown]
# ## 2️⃣ Importovať konkrétny modul a zobraziť jeho dokumentáciu
# **📌 Úloha:** Načítať a zobraziť dokumentáciu modulu math.

# %%
import math, os, sys, datetime, random, builtins
help(math)
# help(os)
# help(sys)
# help(datetime)
# help(random)
# help(builtins)
# Out:
# Help on built-in module builtins:
#
# NAME
#     builtins - Built-in functions, exceptions, and other objects.
#
# DESCRIPTION
#     Noteworthy: None is the `nil' object; Ellipsis represents `...' in slices.
#
# CLASSES
#     object
#         BaseException
#             Exception
#                 ArithmeticError
#                     FloatingPointError
#                     OverflowError
#                     ZeroDivisionError
#                 AssertionError
#                 AttributeError
#                 BufferError
#                 EOFError
#                 ImportError
#                     ModuleNotFoundError
#                 LookupError
#                     IndexError
#                     KeyError
#                 MemoryError
#                 NameError
#                     UnboundLocalError
#                 OSError
#                     BlockingIOError
#                     ChildProcessError
#                     ConnectionError
# ...

# %% [markdown]
# ## 3️⃣ PIP, knižnice/balíčky a ich verzie
#
# **📌 Úloha:** Zobraziť verziu balíčkov a knižníc.
#
# **PIP (package installer for Python)** - Správca Balíčkov pre moduly programovacieho jazyka Python, Tiež napísaný v Pythone, Licencia MIT.
# Dokumentácia PIP: https://pip.pypa.io/en/stable/
#
# **PyPI (The Python Package Index)** - Repozitár/úložisko softvéru pre programovací jazyk Python
# https://pypi.org
# 1

# %%
# __version__, version
import sys, matplotlib, platform, pip, math, os

print(f"matplotlib.__version__: {matplotlib.__version__}")
print(f"platform.__version__: {platform.__version__}")
print(f"pip.__version__: {pip.__version__}")

# Verzia Python
print(f"sys.version: {sys.version}")

# Zabudované moduly nemajú version
#print(f"os.version: {os.__version__}")
#print(math.__version__)
#print(f"math.version: {math.version}")
# Out:
# sys.version: 3.8.20 (default, Mar  4 2025, 17:24:18)
# [GCC 11.4.0]
# matplotlib.__version__: 3.7.5
# platform.__version__: 1.0.8
# pip.__version__: 24.3.1

# %%
# !pip list
# pip install plotly
# pip install bokeh
# pip install seaborn
# pip install matplotlib
# pip install squarify

# !pip install plotly

# %%
# !pip install squarify
import pandas as pd
# Grafy, Diagramy, Vizualizacie
import matplotlib
import plotly
import bokeh
import seaborn
import squarify
import importlib.metadata

print("✅ Moduly/kniznice boli nacitane")
# Zobrazenie verzií knižníc
print(f"Plotly verzia: {plotly.__version__}")
print(f"Bokeh verzia: {bokeh.__version__}")
print(f"Seaborn verzia: {seaborn.__version__}")
print(f"Matplotlib verzia: {matplotlib.__version__}")
print(f"Squarify verzia: {importlib.metadata.version('squarify')}")
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ✅ Moduly/kniznice boli nacitane
# Plotly verzia: 5.24.1
# Bokeh verzia: 3.1.1
# Seaborn verzia: 0.13.2
# Matplotlib verzia: 3.7.5
# Squarify verzia: 0.4.4
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 20 in <module>
#     at line 530 in version(distribution_name)
#     at line 503 in distribution(distribution_name)
#     at line 177 in from_name(cls, name)
# PackageNotFoundError: math

# %% [markdown]
# ## 4️⃣ Modul builthwith

# %%
print(__builtins__)
help(__builtins__)

print(builtins)
help(builtins)
# Out:
# <module 'builtins' (built-in)>
# Help on built-in module builtins:
#
# NAME
#     builtins - Built-in functions, exceptions, and other objects.
#
# DESCRIPTION
#     Noteworthy: None is the `nil' object; Ellipsis represents `...' in slices.
#
# CLASSES
#     object
#         BaseException
#             Exception
#                 ArithmeticError
#                     FloatingPointError
#                     OverflowError
#                     ZeroDivisionError
#                 AssertionError
#                 AttributeError
#                 BufferError
#                 EOFError
#                 ImportError
#                     ModuleNotFoundError
#                 LookupError
#                     IndexError
#                     KeyError
#                 MemoryError
#                 NameError
#                     UnboundLocalError
#                 OSError
#                     BlockingIOError
#                     ChildProcessError
#                     ConnectionError
# ...

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %% [markdown]
# ## 5️⃣ Zabudované funkcie (Built-in Functions)
# - Sú funkcie, ktoré sú priamo dostupné v jazyku Python bez potreby importu ďalších knižníc.
# - Tieto funkcie sú súčasťou samotného Pythonu a poskytujú základné operácie na manipuláciu s dátami, ako aj rôzne nástroje na efektívnejšie písanie kódu.
# - Je ich celkovo 71 v Pythone 3.13.2
#
# https://docs.python.org/3/library/functions.html
#
# Príklady Python Built-in Functions:
#
# 1. print() – na výpis textu do konzoly.
# 2. len() – na získanie dĺžky objektu (napr. zoznamu, reťazca).
# 3. type() – na zistenie typu objektu.
# 4. int() – na konverziu hodnoty na celé číslo.
# 5. str() – na konverziu hodnoty na reťazec.
# 6. sum() – na spočítanie súčtu prvkov v iterovateľnom objekte.
# 7. max() – na získanie najväčšieho prvku v iterovateľnom objekte.
# 8. min() – na získanie najmenšieho prvku v iterovateľnom objekte.
# 9. range() – na generovanie sekvencie čísel.
# 10. sorted() – na zoradenie iterovateľného objektu.
# 11. abs() – vracia absolútnu hodnotu čísla.
# 12. all() – vráti True, ak všetky prvky v iterovateľnom objekte sú pravdivé.
# 13. any() – vráti True, ak aspoň jeden prvok v iterovateľnom objekte je pravdivý.
# 14. enumerate() – vráti iterátor, ktorý generuje index a hodnotu z iterovateľného objektu.
# 15. filter() – vytvorí nový iterovateľný objekt, ktorý obsahuje prvky zoznamu, ktoré spĺňajú danú podmienku.
# 16. map() – aplikuje funkciu na každý prvok v iterovateľnom objekte.
# 17. id() – vráti jedinečný identifikátor objektu v pamäti.
# 18. isinstance() – skontroluje, či je objekt inštanciou určitého typu.
# 19. reversed() – vráti reverznú verziu iterovateľného objektu.
# 20. zip() – vytvorí iterátor, ktorý agreguje prvky z dvoch alebo viacerých iterovateľných objektov do n-tíc.

# %% [markdown]
# ### Funkcia all()
# - Vracia True, ak všetky položky v iterovateľnom objekte sú pravdivé (alebo ak je iterovateľný objekt prázdny).
# - Používa na overenie, či sú všetky prvky v iterovateľnom objekte (napr. zoznam, množina, atď.) pravdivé. Ak sú všetky hodnoty pravdivé (tzn. hodnoty, ktoré sa v kontexte Pythonu hodnotia ako True), funkcia vráti hodnotu True.
# - Ak aspoň jedna hodnota v iterovateľnom objekte je nepravdivá (tzn. hodnoty ako False, None, prázdne reťazce, čísla 0, atď.), funkcia vráti False.
# - Veľmi užitočná v prípadoch, kde chcete skontrolovať, či všetky prvky spĺňajú určitú podmienku, bez toho, aby ste museli iterovať cez každý prvok manuálne.
#
# **Výhody:**
# 1. Umožňuje jednoducho a efektívne skontrolovať pravdivosť viacerých podmienok naraz.
# 2. Zjednodušuje zápis kódu, pretože sa nemusí používať cyklus alebo zložité podmienky.

# %%
# Zistiť, či všetky prvky v zozname sú pravdivé:
# Príklad pre funkciu all()
zoznam = [True, True, False]
vysledok = all(zoznam)
print(vysledok)  # Výstup: False

# Prázdny zoznam
empty_list = []
print(all(empty_list))  # Výstup: True
# Out:
# False
# True

# %%
# Skontrolovať, či všetky hodnoty v zozname sú kladné čísla:

numbers = [1, 2, 3, 4]
print(all(n > 0 for n in numbers))  # Vráti True, pretože všetky čísla sú kladné
# Out:
# True

# %%
# Skontrolovať, či všetky reťazce v zozname nie sú prázdne:

strings = ['apple', 'banana', 'cherry']
print(all(s != '' for s in strings))  # Vráti True, pretože žiadny reťazec nie je prázdny
# Out:
# True

# %% [markdown]
# ### Funkcia any()
# - Vracia True, ak aspoň jedna položka v iterovateľnom objekte je pravdivá.
# - Používa na overenie, či aspoň jeden prvok v iterovateľnom objekte (napr. zoznam, množina, atď.) je pravdivý. Ak aspoň jeden prvok hodnotí ako True (tzn. nie je False, None, prázdny reťazec, číslo 0, atď.), funkcia vráti hodnotu True.
# - Ak všetky prvky sú nepravdivé (tzn. hodnoty ako False, None, prázdne reťazce, čísla 0, atď.), funkcia vráti False.
# - Veľmi užitočná, keď potrebujete vedieť, či niektorý prvok spĺňa určitú podmienku, bez toho, aby ste museli prehľadávať celý objekt.
#
# **Výhody:**
# 1. Funkcia any() je ideálna na rýchlu kontrolu, či existuje aspoň jeden pravdivý prvok v iterovateľnom objekte.
# 2. Umožňuje urobiť túto kontrolu bez potreby cyklov alebo zložitých podmienok.

# %%
# Zistiť, či aspoň jedna hodnota v zozname je True:

# Príklad pre funkciu any()
zoznam = [False, False, True]
vysledok = any(zoznam)
print(vysledok)  # Výstup: True

# Všetky položky sú False
empty_list = [False, False, False]
print(any(empty_list))  # Výstup: False

# %%
# Skontrolovať, či aspoň jedno číslo v zozname je kladné:

numbers = [-1, -2, 3, -4]
print(any(n > 0 for n in numbers))  # Vráti True, pretože číslo 3 je kladné

# %%
# Skontrolovať, či aspoň jeden reťazec v zozname nie je prázdny:

strings = ['', '', 'cherry']
print(any(s != '' for s in strings))  # Vráti True, pretože 'cherry' nie je prázdny

# %% [markdown]
# ### Funkcia bytearray()
# - Vytvára objekt typu bytearray, ktorý je mutable (modifikovateľný) a slúži na ukladanie bajtov.
# - Používa na vytvorenie mutable (meniteľného) typu dát, ktorý reprezentuje sekvenciu bajtov.
# - Tento typ dát je podobný obyčajnému typu bytes, ale na rozdiel od neho umožňuje upravovať (modifikovať) obsah, čo znamená, že je možné pridávať, meniť alebo mazať bajty.
# - Ideálna na manipuláciu s binárnymi dátami, kde potrebujete flexibilitu a výkon pri modifikácii bajtov v pamäti.
#
# **Výhody:**
# 1. Mutable: Na rozdiel od bytes, ktoré sú nemenné, bytearray umožňuje priamu manipuláciu s obsahom.
# 2. Efektívnosť: Je to efektívny spôsob na prácu s binárnymi dátami alebo kódovanými reťazcami, ktoré sa potrebujú meniť.
# 3. Kompatibilita: Používa sa na prácu s binárnymi súbormi alebo komunikáciou cez protokoly, kde je potrebné prispôsobovať bajty.

# %%
# Vytvorenie prázdneho bytearray:

b = bytearray()
print(b)  # Vytlačí: bytearray(b'')
# Out:
# bytearray(b'')

# %%
# Vytvorenie bytearray zo zoznamu čísel:

# Príklad pre funkciu bytearray()
bajty = bytearray([65, 66, 67])  # ASCII hodnoty pre 'A', 'B', 'C'
print(bajty)  # Výstup: bytearray(b'ABC')

# Modifikácia
bajty[0] = 90  # Zmena prvého znaku na 'Z'
print(bajty)  # Výstup: bytearray(b'ZBC')
# Out:
# bytearray(b'ABC')
# bytearray(b'ZBC')

# %%
# Vytvorenie bytearray z reťazca pomocou kódovania:
b = bytearray('hello', 'utf-8')
print(b)  # Vytlačí: bytearray(b'hello')

# %% [markdown]
# ### Funkcia callable()
# - Skontroluje, či je objekt volateľný (t. j. či môže byť zavolaný ako funkcia).
# - Používa na zistenie, či je objekt volateľný, tzn. či sa dá zavolať ako funkcia alebo metóda.
# - Funkcia callable() vráti hodnotu True, ak je objekt volateľný (napríklad funkcia, metóda, trieda s metódou __call__), a False, ak nie je.
# - Umožňuje flexibilne zistiť, či objekt podporuje volanie, čo je užitočné pri práci s funkciami, metódami alebo inými objekty, ktoré implementujú metódu __call__.
#
# **Výhody:**
# 1. Funkcia callable() je užitočná na dynamickú kontrolu, či je objekt funkciou alebo metódou, a teda ho môžeme zavolať.
# 2. Je to praktické pri práci s objektmi, ktoré môžu byť rôzneho typu a nie vždy je zaručené, že sú volateľné.

# %%
# Skontrolovať, či je funkcia volateľná:

# Príklad pre funkciu callable()
def funkcia():
    pass

objekt = 123

print(callable(funkcia))  # Výstup: True
print(callable(objekt))   # Výstup: False
# Out:
# True
# False

# %%
# Skontrolovať, či je obyčajný objekt volateľný (nie je)
my_string = "Hello, World!"
print(callable(my_string))  # Vráti False, pretože reťazec nie je volateľný
# Out:
# False

# %%
# Skontrolovať, či je trieda volateľná (ak má metódu __call__):

class MyClass:
    def __call__(self):
        return "Som volatelna Trieda (callable)!"

obj = MyClass()
print(callable(obj))  # Vráti True, pretože MyClass má metódu __call__
# Out:
# True

# %% [markdown]
# ### Funkcia complex()
# - Vytvára komplexné číslo. Môže prijať reálnu a imaginárnu časť ako argumenty.
# - Používa sa na vytvorenie komplexného čísla.
# - Komplexné číslo je číslo, ktoré obsahuje reálnu a imaginárnu časť, a je vo forme a + bj, kde a je reálna časť a b je imaginárna časť, pričom j je imaginárna jednotka (v Pythone je to j, nie i, ako je bežné v matematike).
# - Užitočná pri práci s komplexnými číslami v Pythone a je nevyhnutná na ich tvorbu a manipuláciu.
#
# **Výhody:**
# 1. Funkcia complex() umožňuje jednoducho vytvoriť komplexné čísla, ktoré sú dôležité v rôznych oblastiach matematiky, inžinierstva a veda (napr. v analýze signálov, Fourierovej analýze, kvantovej fyzike, atď.).
# 2. Python automaticky podporuje aritmetiku s komplexnými číslami, vrátane sčítať, odčítať, násobiť a deliť komplexné čísla.

# %%
# Vytvorenie komplexného čísla z reálnej a imaginárnej časti:

c = complex(2, 3)
print(c)  # Vytlačí: (2+3j)
# Out:
# (2+3j)
# (5+0j)

# %%
# Vytvorenie komplexného čísla len z reálnej časti (imaginárna časť je 0):

c = complex(4)
print(c)  # Vytlačí: (4+0j)
# Out:
# (4+0j)

# %%
# Vytvorenie komplexného čísla z reťazca (dohodnutý formát):

c = complex('2+3j')
print(c)  # Vytlačí: (2+3j)
# Out:
# (2+3j)

# %%
# Získanie reálnej a imaginárnej časti komplexného čísla:

c = complex(3, 4)
print(c.real)  # Vytlačí: 3.0
print(c.imag)  # Vytlačí: 4.0
# Out:
# 3.0
# 4.0

# %% [markdown]
# ### Funkcia delattr()
# - Slúži na vymazanie atribútu objektu.
# - Používa na odstránenie (vymazanie) atribútu z objektu.
# - Funkcia vyžaduje 2 argumenty: objekt a reťazec obsahujúci názov atribútu, ktorý sa má odstrániť.
# - Funkcia delattr() je výkonný nástroj na dynamické odstránenie atribútov z objektov v Pythonu.
#
# **Výhody:**
# 1. Funkcia delattr() je užitočná, keď potrebujete dynamicky upraviť objekt a odstrániť atribúty počas behu programu.
# 2. Je to efektívny spôsob, ako vymazať atribúty, ak už nie sú potrebné, čím šetríte pamäť a udržiavate objekt v čistejšom stave.

# %%
# Odstránenie atribútu z objektu:

class Osoba:
    def __init__(self, meno, vek):
        self.meno = meno
        self.vek = vek

osoba = Osoba("Miroslav", 30)

# Zobrazenie atribútov
print(osoba.meno)  # Výstup: Miroslav

# Vymazanie atribútu
delattr(osoba, "meno")

# Pokus o prístup k vymazanému atribútu vyvolá chybu
# print(osoba.meno)  # Chyba: AttributeError
# Out:
# Miroslav

# %% [markdown]
# ### Funkcia enumerate()
# - Používa sa na získanie indexu a hodnoty v iterovateľnom objekte.
# - Môže byť užitočná na získanie indexu v kombinácii s iterovaním cez rôzne objekty, napríklad pri spracovaní zoznamu s rôznymi dátovými typmi.
# - Na získanie indexu a hodnoty zoznamu (alebo iného iterovateľného objektu) počas iterácie.
# - Táto funkcia vracia iterátor, ktorý generuje dvojice, kde prvý prvok je index a druhý prvok je hodnota z iterovateľného objektu.
# - Veľmi užitočná, keď potrebujete mať prístup k indexu prvkov v iterovateľnom objekte, najmä pri práci s cyklami, kde index a hodnota potrebujú byť spracované súčasne.
#
# **Výhody:**
# 1. Funkcia enumerate() zjednodušuje prácu s indexmi počas iterácie, pretože vám umožňuje získať index a hodnotu súčasne bez potreby ručne počítať index.
# 2. Použitie enumerate() v iteráciách je efektívne a kód je čistejší, než keby ste použili range() a len() na získanie indexu.

# %%
# Získanie indexu a hodnoty zo zoznamu

animals = ['cat', 'dog', 'rabbit']
for index, animal in enumerate(animals):
    print(index, animal)

# Vytlačí:
# 0 cat
# 1 dog
# 2 rabbit
# Out:
# 0 cat
# 1 dog
# 2 rabbit

# %%
# Získanie indexu a hodnoty zo zoznamu s iným počiatočným indexom
animals = ['cat', 'dog', 'rabbit']
for index, animal in enumerate(animals, start=1):
    print(index, animal)
# Vytlačí:
# 1 cat
# 2 dog
# 3 rabbit
# Out:
# 1 cat
# 2 dog
# 3 rabbit

# %%
# Príklad pre funkciu enumerate() s reťazcom
retezec = "Python"

for index, znak in enumerate(retezec):
    print(f"Index: {index}, Znak: {znak}")
# Out:
# Index: 0, Znak: P
# Index: 1, Znak: y
# Index: 2, Znak: t
# Index: 3, Znak: h
# Index: 4, Znak: o
# Index: 5, Znak: n

# %% [markdown]
# ### Funkcia eval()
# - vyhodnotí reťazec ako Python kód.

# %%
# Príklad pre funkciu eval()
vysledok = eval("3 + 5")
print(vysledok)  # Výstup: 8

# Využitie eval() na vyhodnotenie výrazu zo vstupu
vysledok2 = eval("2 * (3 + 4)")
print(vysledok2)  # Výstup: 14
# Out:
# 8
# 14

# %% [markdown]
# ### Funkcia exec()
# - Spúšťa Python kód z reťazca.
# - Slúži na vykonanie (vyhodnotenie) reťazca, ktorý obsahuje platný Python výraz. Tento reťazec sa spracuje ako kód, ktorý sa vykoná v rámci aktuálneho kontextu (súboru, skriptu, atď.).
# - Funkcia eval() je veľmi silná, ale môže byť nebezpečná, ak sa použije s neovereným vstupom, pretože môže vykonať akýkoľvek Python kód.
# - Používanie eval() sa vo všeobecnosti neodporúča, pokiaľ nie ste si istí, že vstupy sú bezpečné. Ak potrebujete bezpečne vyhodnotiť výrazy, zvážte použitie funkcií ako ast.literal_eval(), ktorá vyhodnocuje len literály, a teda je bezpečnejšia.
#
# **Výhody:**
# 1. eval() môže byť užitočný na dynamické vykonávanie kódu, ktorý je definovaný ako reťazec.
# 2. Umožňuje vyhodnocovať výrazy, ktoré môžu byť určené až počas behu programu (napr. zo vstupu používateľa, súborov, atď.).
#
# **Nevýhody:**
# 1. Bezpečnostné riziko: Ak sa použije s neovereným vstupom (napr. od používateľa), môže byť veľmi nebezpečná, pretože môže vykonať ľubovoľný kód. Tento problém sa dá minimalizovať tým, že sa eval() používa iba s dôveryhodnými dátami alebo sa obmedzí prístup k nebezpečným funkciám (napr. importovanie knižníc).
# 2. Náročnosť na údržbu: Používanie eval() môže spôsobiť, že kód bude ťažšie čitateľný a údržbový.

# %%
# Príklad pre funkciu exec()
kod = """
def pozdrav():
    print("Ahoj, svet!")
"""

exec(kod)  # Definuje funkciu pozdrav()
pozdrav()  # Výstup: Ahoj, svet!
# Out:
# Ahoj, svet!

# %%
# Vyhodnotenie matematického výrazu:

expression = "3 * (4 + 2)"
result = eval(expression)
print(result)  # Vytlačí: 18
# Out:
# 18

# %%
# Vyhodnotenie funkcie v reťazci:

def add(a, b):
    return a + b

result = eval('add(3, 4)')
print(result)  # Vytlačí: 7
# Out:
# 30

# %%
# Bezpečnostné riziko (nebezpečné použitie s neovereným vstupom):

user_input = "__import__('os').system('echo Hello')"
eval(user_input)  # Môže vykonať nebezpečný kód a poškodiť systém
# Out:
# 0

# %% [markdown]
# ### Funkcia filter()
# - Filtruje iterovateľný objekt na základe funkcie, ktorá vracia True alebo False.
# - Môže byť použitá aj na filtrovanie reťazcov podľa určitých podmienok.
# - Slúži na filtrovanie prvkov z iterovateľného objektu podľa podmienky definovanej funkciou. Táto funkcia vracia iterátor, ktorý obsahuje len tie prvky, ktoré splnia podmienky v zadanom filtri.
# - Veľmi užitočná, keď potrebujete vybrať len určité hodnoty zo sekvencie, ktoré spĺňajú preddefinovanú podmienku.
#
# **Výhody:**
# 1. filter() je efektívny spôsob na filtrovanie údajov v iterovateľných objektoch bez potreby manuálneho cyklu.
# 2. Môžete filtrovať dáta na základe dynamických podmienok, ktoré môžu byť definované funkciami alebo lambda výrazy.
# 3. Funkcia vracia iterátor, čo znamená, že je pamäťovo efektívna a nevyžaduje vytváranie celej kópie filtrovaných dát.
#
# **Nevýhody:**
# 1. Funkcia filter() vracia iterátor, čo znamená, že je potrebné ju previesť na zoznam alebo inú kolekciu, ak chcete pracovať s výsledkami priamo (napr. cez list(), tuple(), atď.).
# 2. Môže byť menej čitateľná, ak sa používa veľmi komplexná filtračná funkcia.

# %%
# Základné filtrovanie parnych cisel s vlastnou funkciou
zoznam = [1, 2, 3, 4, 5, 6]

# Funkcia, ktorá vracia True pre párne čísla
def je_parne(cislo):
    return cislo % 2 == 0

vysledok = filter(je_parne, zoznam)

# Prevod na zoznam a zobrazenie výsledku
print(list(vysledok))  # Výstup: [2, 4, 6]
# Out:
# [2, 4, 6]

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = filter(lambda x: x % 2 == 0, numbers)
print(list(result))  # Vytlačí: [2, 4, 6]
# Out:
# [2, 4, 6]

# %%
# Základné filtrovanie: Filtrovanie čísel zoznamu, ktoré sú väčšie ako 5:
numbers = [1, 2, 3, 4, 5, 6, 7, 8]
result = filter(lambda x: x > 5, numbers)
print(list(result))  # Vytlačí: [6, 7, 8]
# Out:
# [6, 7, 8]

# %%
# Príklad pre funkciu filter() s reťazcami
zoznam_retezcov = ["python", "java", "c++", "ruby", "javascript"]

# Funkcia, ktorá vracia True pre reťazce dlhšie ako 4 znaky
def dlhy_retezec(retezec):
    return len(retezec) > 4

vysledok = filter(dlhy_retezec, zoznam_retezcov)

# Prevod na zoznam a zobrazenie výsledku
print(list(vysledok))  # Výstup: ['python', 'javascript']
# Out:
# ['python', 'javascript']

# %%
# Filtrovanie reťazcov, ktoré začínajú písmenom "a":

words = ['apple', 'banana', 'avocado', 'cherry']
result = filter(lambda word: word.startswith('a'), words)
print(list(result))  # Vytlačí: ['apple', 'avocado']
# Out:
# ['apple', 'avocado']

# %%
# Funkcia vracajúca None (vyberá iba pravdivé hodnoty): Filtrovanie iba tých hodnôt, ktoré sú True (neprázdne, ne-nulové):
values = [0, 1, False, True, None, 'hello']
result = filter(None, values)
print(list(result))  # Vytlačí: [1, True, 'hello']
# Out:
# [1, True, 'hello']

# %% [markdown]
# ### Funkcia frozenset()
# - Vytvára nemennú (immutable) množinu.
# - Užitočná pri vytváraní nemenných množín, ktoré sa používajú napríklad na operácie s nepozmieňateľnými údajmi.
# - Na vytvorenie nezmenného (immutable) množiny.
# - Množiny (sets) v Pythone sú kolekcie, ktoré neobsahujú duplicitné prvky a umožňujú rýchly prístup k prvkom.
# - Rozdiel medzi množinou (set()) a neprístupnou množinou (frozenset()) je ten, že frozenset je nemenný, tzn. po jeho vytvorení sa jeho obsah nedá meniť (nepridávajú sa nové prvky, ani sa neodstraňujú existujúce).
# - Ideálna, keď potrebujete použitie množiny s garantovanou nemennosťou a bez rizika modifikácií počas práce s dátami.
#
# **Výhody:**
# 1. frozenset() je užitočné, keď potrebujete množinu, ktorá by sa nemala meniť, ako napríklad pri použití ako kľúč v slovníku alebo pri operáciách s množinami, kde nechcete povoliť neúmyselné zmeny.
# 2. Funguje podobne ako množina, ale poskytuje ochranu pred neúmyselnými modifikáciami.
#
# **Nevýhody:**
# 1. Na rozdiel od bežnej množiny, nemôžete pridať ani odstrániť prvky z frozenset po jeho vytvorení.
# 2. Ak potrebujete meniť obsah, budete musieť použiť obyčajnú množinu (set()).

# %%
# Vytvorenie frozenset zo zoznamu:
mnozina = frozenset([1, 2, 3, 4, 5])

# Zobrazenie množiny
print(mnozina)  # Výstup: frozenset({1, 2, 3, 4, 5})

# Pokus o pridať prvok spôsobí chybu, pretože frozenset je nemenný
# mnozina.add(6)  # Chyba: AttributeError

# %%
# Porovnanie s množinou (set()):
my_set = {1, 2, 3}
frozen_set = frozenset([1, 2, 3])

print(my_set == frozen_set)  # Vytlačí: True, pretože obsahujú rovnaké prvky
# Out:
# True

# %%
# Operacie s frozenset()
mnozina = frozenset([1, 2, 3, 4, 5])

# Použitie frozenset v kombinácii s operáciami
dalsia_mnozina = frozenset([4, 5, 6, 7])

# Prienik dvoch množín
prienik = mnozina & dalsia_mnozina
print(prienik)  # Výstup: frozenset({4, 5})

# Spojenie dvoch frozenset
zjednotenie = mnozina | dalsia_mnozina
print(zjednotenie)  # Výstup: frozenset({1, 2, 3, 4, 5, 6, 7})
# Out:
# frozenset({4, 5})
# frozenset({1, 2, 3, 4, 5, 6, 7})

# %% [markdown]
# ### Funkcia globals()
# - Vracia globálny symbolový slovník (dictionary), ktorý obsahuje všetky globálne premenné a funkcie v aktuálnom module.
# - Tento slovník obsahuje názvy premenných a ich hodnoty, ktoré sú definované v globálnom rozsahu programu (mimo všetkých funkcií alebo tried).
# - Funkcia globals() umožňuje dynamicky pristupovať k týmto premenným alebo ich upravovať počas behu programu.
# - Veľmi silný nástroj, ktorý umožňuje manipuláciu s globálnymi dátami v Pythone, ale malo by sa s ňou zaobchádzať opatrne, aby sa predišlo neúmyselným zmenám v globálnych premenných.
#
# **Výhody:**
# 1. globals() je užitočné, ak potrebujete pristupovať alebo manipulovať s globálnymi premennými počas behu programu.
# 2. Pomáha pri dynamických operáciách, ako je evaluácia kódu alebo vytváranie nových premenných alebo funkcií.
#
# **Nevýhody:**
# 1. Bezpečnostné riziká: Použitie globals() na dynamickú manipuláciu s globálnymi premennými môže viesť k neúmyselným chybám alebo bezpečnostným problémom, najmä ak pracujete s neoverenými dátami.
# 2. Kód môže byť menej čitateľný, ak sa premenné alebo funkcie manipulujú priamo cez globals().

# %%
# Zobrazenie všetkých globálnych premenných:

a = 10
b = 20

# Zobrazenie globálnych premenných
print(globals())  # Výstup: {'__name__': '__main__', '__doc__': None, '__package__': None, 'a': 10, 'b': 20, ...}
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '# Zobrazenie zoznamu štandardných Python modulov bez týchto varovaní\n\n# pkgutil: Tento modul je súčasťou Pythonu a poskytuje funkcie na prácu s balíkmi a modulmi. Pomáha v navigovaní a inšpekcii nainštalovaných balíkov.\n\n# sys: Tento modul poskytuje prístup k niektorým premenným a funkciám, ktoré ovládajú prostredie Pythonu, ako sú argumenty príkazového riadku, systémové cesty a ďalšie.\n\nimport pkgutil\nimport sys\n\n# Vytvoriť zoznam všetkých dostupných modulov\nmodules = [module.name for module in pkgutil.iter_modules()]\nprint(f"Pocet modulov: {len(modules)}") ', '# Zobrazenie zoznamu štandardných Python modulov bez týchto varovaní\n\n# pkgutil: Tento modul je súčasťou Pythonu a poskytuje funkcie na prácu s b
# ...

# %%
# Získanie hodnoty globálnej premennej a pomocou globals():

a = 5
b = 10
print(globals()['a'])  # Vytlačí: 5
# Out:
# 5

# %%
# Zmena hodnoty globálnej premennej cez globals():

a = 5
globals()['a'] = 100
print(a)  # Vytlačí: 100, pretože sme upravili globálnu premennú 'a' cez globals()
# Out:
# 100

# %%
# Prístup k funkciám definovaným globálne:

# %%
def hello():
    return "Hello, World!"

print(globals()['hello']())  # Vytlačí: Hello, World!
# Out:
# Hello, World!

# %%
# Použitie v dynamickom spúšťaní kódu

x = 1
y = 2

code = 'x + y'
result = eval(code, globals())
print(result)  # Vytlačí: 3
# Out:
# 3

# %% [markdown]
# ### Funkcia iter()
# - Vytvára iterátor z iterovateľného objektu.
# - Slúži na získanie iterátora z iterovateľného objektu, ako sú zoznamy, n-tice, reťazce alebo iné objekty, ktoré podporujú iterovanie.
# - Funkcia iter() vracia objekt, ktorý implementuje metódy __next__() a __iter__(), čo umožňuje iteráciu cez prvky objektu.
# - Je veľmi užitočná, keď potrebujete manuálne spravovať iteráciu cez prvky objektu alebo ak chcete prístup k iterátorom pre ďalšie spracovanie
#
# **Výhody:**
# 1. iter() umožňuje explicitne získať iterátor z iterovateľného objektu, čo je užitočné, ak chcete manuálne kontrolovať priebeh iterácie pomocou next().
# 2. Môžete používať iter() aj na objekty, ktoré nie sú natrvalo v pamäti (napr. generátory), čo umožňuje efektívnu správu pamäte.
#
# **Nevýhody:**
# 1. Pri použití next() s iterátorom je potrebné zaobchádzať opatrne, pretože po vyčerpaní iterátora (keď už nie sú ďalšie prvky na iterovanie) sa vyvolá výnimka StopIteration, čo môže spôsobiť nežiaduce chyby, ak sa neprimerane nezachytí.

# %%
# Vytvorenie iterátora z zoznamu:

zoznam = [1, 2, 3, 4, 5]

# Vytvorenie iterátora
it = iter(zoznam)

# Iterovanie cez iterátor
print(next(it))  # Výstup: 1
print(next(it))  # Výstup: 2
# Out:
# 1
# 2

# %%
# Použitie v cykle for (automatická iterácia):
numbers = [1, 2, 3, 4, 5]
it = iter(numbers)
for num in it:
    print(num)
    
# Vytlačí:
# 1
# 2
# 3
# 4
# 5
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Ručné použitie funkcie next() s iterátorom:
words = ['apple', 'banana', 'cherry']
it = iter(words)
print(next(it))  # Vytlačí: apple
print(next(it))  # Vytlačí: banana
print(next(it))  # Vytlačí: cherry
# Out:
# apple
# banana
# cherry

# %%
# Použitie s prázdnym objektom (vyvolá StopIteration):
empty_list = []
it = iter(empty_list)

try:
    print(next(it))
except StopIteration:
    print("Koniec iterácie")  # Vytlačí: Koniec iterácie
# Out:
# Koniec iterácie

# %%
# Použitie iterátora s funkciou next() a východzou hodnotou:

numbers = [1, 2, 3]
it = iter(numbers)
print(next(it, 'Koniec'))  # Vytlačí: 1
print(next(it, 'Koniec'))  # Vytlačí: 2
print(next(it, 'Koniec'))  # Vytlačí: 3
print(next(it, 'Koniec'))  # Vytlačí: Koniec (pretože iterácia skončila)
# Out:
# 1
# 2
# 3
# Koniec

# %% [markdown]
# ### Funkcia locals()
# - Vracia lokálny symbolový slovník, ktorý obsahuje lokálne premenné v aktuálnej funkcii alebo bloku kódu.
# - Slovník obsahujúci všetky lokálne premenné a ich hodnoty v aktuálnom rozsahu (kontexte).
# - Tento rozsah môže byť funkcia, metóda, alebo iný blok kódu, kde sú premenné definované.
# - Umožňuje dynamicky pristupovať k týmto premenným alebo ich upravovať počas behu programu.
# - Silný nástroj na manipuláciu a pristupovanie k lokálnym premenným, ale mala by sa používať opatrne, najmä pri dynamických zmenách hodnôt.
#
# **Výhody:**
# 1. locals() je užitočné na dynamické zistenie alebo manipuláciu s premennými v aktuálnom rozsahu.
# 2. Môže byť použité v debugovaní alebo pri generovaní kódu, kde potrebujete prístup k aktuálnym hodnotám premenných.
#
# **Nevýhody:**
# 1. Zmena hodnôt cez locals() nemusí vždy fungovať, najmä mimo funkcie, pretože niektoré lokalizované premenné môžu byť optimalizované a neumožňujú priame zmeny.
# 2. Manipulácia s lokálnymi premennými cez locals() môže byť riskantná, pretože môže spôsobiť neúmyselné chyby v kóde.

# %%
# Zobrazenie všetkých lokálnych premenných vo funkcii:

def funkcia():
    x = 5
    y = 10
    print(locals())  # Výstup: {'x': 5, 'y': 10}

funkcia()

# print(locals())
# Out:
# {'x': 5, 'y': 10}
# ...

# %%
# Použitie locals() na prístup k lokálnym premenným:
def my_function():
    a = 5
    b = 15
    print(locals()['a'])  # Vytlačí: 5
    print(locals()['b'])  # Vytlačí: 15

my_function()
# Out:
# 5
# 15

# %%
# Dynamické pridanie lokálnej premennej pomocou locals():

def my_function():
    a = 10
    locals()['new_var'] = 50
    print(locals()['new_var'])  # Vytlačí: 50

my_function()
# Out:
# 50

# %% [markdown]
# ### Funkcia map()
# - Aplikuje funkciu na každý prvok iterovateľného objektu (napr. zoznamu).
# - Používa na aplikovanie danej funkcie na každý prvok v iterovateľnom objekte (ako je zoznam, n-tica, atď.).
# - Vracia iterátor, ktorý obsahuje výsledky aplikovania funkcie na každý prvok vstupného iterovateľného objektu.
# - Na spracovanie dát, kde je potrebné použiť rovnakú operáciu na každý prvok v sekvencii.
# - Veľmi užitočná, keď potrebujete aplikovať rovnakú operáciu na každý prvok v iterovateľnom objekte, najmä pri práci s veľkými množstvami dát, kde je efektívnosť pamäte dôležitá.
#
# **Výhody:**
# 1. map() je efektívna na aplikovanie rovnakých operácií na každý prvok v iterovateľnom objekte bez potreby použitia explicitného cyklu for.
# 2. Vrátený iterátor je pamäťovo efektívny, pretože spracováva dáta "na vyžiadanie", čo šetrí pamäť pri práci s veľkými dátovými množinami.
#
# **Nevýhody:**
# 1. Funkcia map() vracia iterátor, takže je potrebné ju previesť na zoznam alebo inú kolekciu (napr. cez list()), ak chcete pracovať s výsledkami priamo.
# 2. Ak je funkcia alebo použitie zložitejšie, môže byť menej čitateľné ako klasický cyklus for.

# %%
# Základné použitie s jedným iterovateľným objektom: Aplikovanie funkcie na každý prvok zoznamu
zoznam = [1, 2, 3, 4, 5]

# Funkcia na zdvojnásobenie hodnoty
def zdvojnasobit(cislo):
    return cislo * 2

# Použitie map() na aplikovanie funkcie na každý prvok
vysledok = map(zdvojnasobit, zoznam)

# Prevod na zoznam a zobrazenie výsledku
print(list(vysledok))  # Výstup: [2, 4, 6, 8, 10]
# Out:
# [2, 4, 6, 8, 10]

# %%
numbers = [1, 2, 3, 4, 5]
result = map(lambda x: x * 2, numbers)
print(list(result))  # Vytlačí: [2, 4, 6, 8, 10]
# Out:
# [2, 4, 6, 8, 10]

# %%
# Aplikovanie funkcie na reťazce: Pre každé písmeno reťazca aplikujeme funkciu, ktorá ho prevedie na veľké písmeno:
words = ['apple', 'banana', 'cherry']
result = map(str.upper, words)
print(list(result))  # Vytlačí: ['APPLE', 'BANANA', 'CHERRY']
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
# Použitie s definovanou funkciou: Použitie vlastnej funkcie na každú hodnotu zoznamu:

def square(x):
    return x ** 2

numbers = [1, 2, 3, 4]
result = map(square, numbers)
print(list(result))  # Vytlačí: [1, 4, 9, 16]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# # Dáta a Súbory

# %% [markdown]
# # 🗂 Práca s dátami a súbormi
#
# 1. os – Práca s prostredím operačného systému
# 2. shutil - Manipulácia so súbormi a adresármi, ako je ich kopírovanie, presúvanie, mazanie a archivovanie
# 3. pathlib – Efektívna práca s cestami k súborom
# 4. csv – Čítanie, zapisovanie, konvertovanie CSV súboru
# 5. json – Čítanie, zapisovanie, konvertovanie JSON súboru

# %% [markdown]
# ## 🗂 Modul os – Práca s prostredím operačného systému
# - Vhodný pre základné operácie a prácu s environmentálnymi premennými.
#
# 1. os.getcwd() – získa aktuálny pracovný adresár
# 2. os.chdir(path) – zmení aktuálny pracovný adresár na zadaný
# 3. os.listdir(path) – vráti zoznam súborov a adresárov v zadanom adresári
# 4. os.mkdir(path) – vytvorí nový adresár
# 5. os.makedirs(path) – vytvorí adresár aj s neexistujúcimi nadradenými adresármi
# 6. os.remove(path) – odstráni súbor
# 7. os.rmdir(path) – odstráni prázdny adresár
# 8. os.rename(src, dst) – premenováva súbor alebo adresár
# 9. os.path.exists(path) – overí, či daný súbor alebo adresár existuje
# 10. os.path.join(path, paths) – spája cesty do jedného reťazca
# 11. os.path.isabs(path) – zistí, či je cesta absolútna
# 12. os.path.isfile(path) – overí, či je cesta súborom
# 13. os.path.isdir(path) – overí, či je cesta adresárom
# 14. os.path.getsize(path) – vráti veľkosť súboru v bajtoch
# 15. os.environ – slovník obsahujúci environmentálne premenné

# %% [markdown]
# 📌 Úloha: Získať zoznam všetkých súborov v adresári

# %%
import os
print(os.listdir("."))  # Vypíše súbory a priečinky v aktuálnom adresári
# Out:
# ['example.csv', 'data.json', 'data.csv', 'environment.yml', 'lost+found']

# %% [markdown]
# ## 📂 Modul shutil - Manipulácia so súbormi a adresár
# - Ideálny na manipuláciu s celými adresármi a operácie ako kopírovanie, presúvanie a archivovanie.
#
# 1. shutil.copy(src, dst) – skopíruje súbor z src do dst
# 2. shutil.copy2(src, dst) – skopíruje súbor z src do dst, zachováva časové pečiatky
# 3. shutil.copytree(src, dst) – skopíruje celý adresár (vrátane podadresárov) z src do dst
# 4. shutil.move(src, dst) – presunie súbor alebo adresár z src do dst
# 5. shutil.rmtree(path) – odstráni celý adresárový strom (adresáre a súbory)
# 6. shutil.disk_usage(path) – vráti informácie o využití disku pre daný adresár (voľné, použité a celkové miesto)
# 7. shutil.make_archive(base_name, format, root_dir, base_dir) – vytvorí archivovaný súbor (zip, tar, ...), ktorý obsahuje obsah adresára
# 8. shutil.unpack_archive(filename, extract_dir=None) – rozbalí archivovaný súbor do zadaného adresára
# 9. shutil.chown(path, user=None, group=None) – zmení vlastníka a skupinu súboru alebo adresára
# 10. shutil.which(cmd) – vráti cestu k príkazu v systéme alebo None, ak neexistuje

# %% [markdown]
# 📌 Úloha: Skopírovať súbor

# %%
import shutil
shutil.copy("subor.txt", "zaloha.txt")
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 2 in <module>
#     at line 418 in copy(src, dst, follow_symlinks)
#     at line 264 in copyfile(src, dst, follow_symlinks)
# FileNotFoundError: [Errno 2] No such file or directory: 'subor.txt'

# %% [markdown]
# ## 📁 Modul pathlib – Efektívna práca s cestami k súborom
# - Výborný, ak chcete pracovať s cestami pomocou objektovo orientovaného prístupu a využívať moderné a čitateľné rozhranie.
#
# 1. Path() – vytvorí objekt reprezentujúci cestu k súboru alebo adresáru
# 2. Path.cwd() – vráti aktuálny pracovný adresár ako objekt Path
# 3. Path.home() – vráti domovský adresár aktuálneho používateľa
# 4. Path.exists() – skontroluje, či súbor alebo adresár existuje
# 5. Path.is_file() – skontroluje, či je cesta súborom
# 6. Path.is_dir() – skontroluje, či je cesta adresárom
# 7. Path.mkdir() – vytvorí nový adresár
# 8. Path.rename() – premenováva súbor alebo adresár
# 9. Path.rmdir() – odstráni prázdny adresár
# 10. Path.unlink() – odstráni súbor
# 11. Path.glob(pattern) – vráti iterátor obsahujúci všetky súbory, ktoré zodpovedajú danému vzoru (wildcard)
# 12. Path.iterdir() – vráti iterátor cez obsah adresára (súbory a podadresáre)
# 13. Path.stem – vráti názov súboru bez prípony
# 14. Path.suffix – vráti príponu súboru (napr. .txt)
# 15. Path.parent – vráti nadradený adresár
# 16. Path.relative_to() – vráti relatívnu cestu k zadanému adresáru alebo súboru
# 17. Path.resolve() – vráti absolútnu (záverečnú) cestu k súboru alebo adresáru

# %% [markdown]
# 📌 Úloha: Získať veľkosť súboru

# %%
from pathlib import Path
subor = Path("subor.txt")
print(subor.stat().st_size)  # Veľkosť v bajtoch
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 3 in <module>
#     at line 1198 in stat(self)
# FileNotFoundError: [Errno 2] No such file or directory: 'subor.txt'

# %% [markdown]
# 📌 Úloha: Premenovať súbor

# %%
from pathlib import Path
subor = Path("subor.txt")
subor.rename("novy_subor.txt")

# %% [markdown]
# 📌 Úloha: Získať zoznam všetkých súborov v adresári

# %%
from pathlib import Path

# Získanie aktuálneho adresára
current_dir = Path.cwd()

# Vypísanie všetkých súborov a priečinkov v aktuálnom adresári
for item in current_dir.iterdir():
    print(item)
# Out:
# /data/notebook_files/example.csv
# /data/notebook_files/data.json
# /data/notebook_files/data.csv
# /data/notebook_files/environment.yml
# /data/notebook_files/lost+found

# %% [markdown]
# ## 📊 Modul csv – Čítanie CSV súboru do zoznamu slovníkov
#
# **Dialekt (dialect):** súbor nastavení, ktoré určujú, ako sa budú spracovávať CSV súbory. Obsahuje špecifikácie pre rôzne parametre, ako sú:
# - delimiter – znak, ktorý sa používa na oddelenie hodnôt (napr. čiarka ,, bodkočiarka ;).
# - quotechar – znak, ktorý sa používa na ohraničenie hodnôt obsahujúcich oddeľovače alebo špeciálne znaky (napr. úvodzovky ").
# - escapechar – znak, ktorý sa používa na únik pred špeciálnymi znakmi (napr. spätné lomítko \).
# - lineterminator – znak (alebo sekvencia), ktorý sa používa na ukončenie riadku.
# - skipinitialspace – ak je nastavený na True, ignorujú sa medzery po oddeľovačoch.
#
# 1. csv.reader(csvfile, delimiter=',') – číta CSV súbor a vracia iterator na riadky (predpokladá sa, že sú hodnoty oddelené čiarkami)
# 2. csv.writer(csvfile, delimiter=',') – vytvára objekt na zápis do CSV súboru
# 3. csv.DictReader(csvfile) – číta CSV súbor a vracia riadky ako slovníky, kde kľúče sú názvy stĺpcov
# 4. csv.DictWriter(csvfile, fieldnames) – zapisuje riadky do CSV súboru ako slovníky, kde kľúče sú názvy stĺpcov
# 5. csv.field_size_limit(limit) – nastavuje limit veľkosti poľa pre čítanie CSV súboru
# 6. csv.register_dialect(name, delimiter, quotechar, escapechar) – zaregistruje nový dialekt pre CSV formát
# 7. csv.unregister_dialect(name) – odregistrová dialekt podľa názvu
# 8. csv.get_dialect(name) – získa parametre pre zaregistrovaný dialekt

# %% [markdown]
# 📌 Úloha: Načítať dáta zo súboru do zoznamu slovníkov

# %%
import csv

with open("data.csv", newline="", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for riadok in reader:
        print(riadok)
# Out:
# {'Meno': 'Eva', 'Vek': '29'}
# {'Meno': 'Peter', 'Vek': '34'}

# %% [markdown]
# 📌 Úloha: Zapísať zoznam slovníkov do CSV

# %%
data = [{"Meno": "Eva", "Vek": 29}, {"Meno": "Peter", "Vek": 34}]

with open("data.csv", mode="w", newline="", encoding="utf-8") as f:
    fieldnames = ["Meno", "Vek"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

# %% [markdown]
# 📌 Úloha: Nastaviť limit pre veľkosť poľa na 1000 znakov.

# %%
import csv

# Nastavenie limitu veľkosti poľa na 1000 znakov
csv.field_size_limit(1000)

# Vytvorenie a zápis do CSV súboru s veľkými hodnotami
with open('example.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['ID', 'Name', 'Description'])
    writer.writerow([1, 'Item 1', 'A' * 1500])  # Veľký popis

# Čítanie CSV súboru
with open('example.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        print(row)
# Out:
# ['ID', 'Name', 'Description']
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 15 in <module>
# Error: field larger than field limit (1000)

# %% [markdown]
# ## 📜 Modul json – Čítanie, zapisovanie, konvertovanie JSON súboru
# 1. json.load(file) – načíta JSON dáta zo súboru a vráti ich ako Python objekty
# 2. json.loads(s) – načíta JSON dáta z reťazca a vráti ich ako Python objekty
# 3. json.dump(obj, file) – zapíše Python objekt do súboru vo formáte JSON
# 4. json.dumps(obj) – konvertuje Python objekt na JSON reťazec
# 5. json.JSONDecodeError – výnimka vyvolaná pri chybách dekódovania JSON
# 6. json.dumps(obj, indent=None, separators=None) – konvertuje Python objekt na JSON reťazec s možnosťou formátovania (napr. nastavenie odsadenia)
# 7. json.load(file, object_hook=None) – načíta JSON dáta zo súboru a umožňuje definovať vlastnú funkciu na spracovanie objektov (pomocou object_hook)
# 8. json.dumps(obj, sort_keys=False) – konvertuje Python objekt na JSON reťazec, pričom umožňuje zoradiť kľúče (nastavením sort_keys=True)

# %% [markdown]
# 📌 Úloha: Konvertovať Python slovník na JSON

# %%
import json
data = {"meno": "Igor", "vek": 30}
json_data = json.dumps(data)
print(json_data)  # {"meno": "Igor", "vek": 30}
# Out:
# {"meno": "Igor", "vek": 30}

# %% [markdown]
# 📌 Úloha: Zapísať JSON do súboru

# %%
with open("data.json", "w") as f:
    json.dump(data, f)

# %% [markdown]
# 📌 Úloha: Formátovanie JSON

# %%
import json

# Python objekt (slovník)
data = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

# Konverzia Python objektu na JSON reťazec s odsadením (indent) a separátormi
json_string = json.dumps(data, indent=4, separators=(',', ': '))

# Výpis formátovaného JSON reťazca
print(json_string)
# Out:
# {
#     "name": "Alice",
#     "age": 30,
#     "city": "New York"
# }

# %% [markdown]
# # Čas, Dátum a Generovanie Dát

# %% [markdown]
# # ⏳ Práca s časom a generovanie dát
#
# 1. datetime – Práca s dátumom a časom
# 2. random – Generovanie náhodných hodnôt

# %% [markdown]
# ## ⏳ Modul datetime – Práca s dátumom a časom
# 1. datetime.now() – získa aktuálny dátum a čas
# 2. datetime.today() – získa aktuálny dátum (bez času)
# 3. datetime.fromtimestamp(timestamp) – vytvorí objekt datetime zo zadaného timestampu
# 4. datetime.utcfromtimestamp(timestamp) – vytvorí objekt datetime zo zadaného timestampu v UTC
# 5. datetime.strptime(date_string, format) – prevedie reťazec na datetime objekt podľa zadaného formátu
# 6. datetime.strftime(format) – prevedie objekt datetime na reťazec podľa zadaného formátu
# 7. datetime.timedelta() – reprezentuje časový rozdiel (dní, hodín, minút)
# 8. datetime.date() – získa iba dátum (bez času) z objektu datetime
# 9. datetime.time() – získa iba čas (bez dátumu) z objektu datetime
# 10. datetime.combine(date, time) – kombinuje objekt date a time do objektu datetime
# 11. datetime.replace(year, month, day, hour, minute, second, microsecond) – umožňuje zmeniť časť objektu datetime
# 12. datetime.month, datetime.day, datetime.year – extrahuje mesiac, deň a rok z objektu datetime

# %% [markdown]
# 📌 Úloha: Získať aktuálny dátum a čas

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2025-03-18 21:08:08.614509

# %% [markdown]
# 📌 Úloha: Formátovať dátum
#
# 1. %Y – Rok (4 číslice, napr. 2025)
# 2. %y – Rok (2 číslice, napr. 25)
# 3. %m – Mesiac (2 číslice, napr. 03)
# 4. %b – Skrátený názov mesiaca (Jan, Feb, Mar, ...)
# 5. %B – Názov mesiaca (Január, Február, ...)
# 6. %d – Deň mesiaca (2 číslice, napr. 09)
# 7. %j – Deň v roku (3 číslice, napr. 009)
# 8. %A – Názov dňa v týždni (Pondelok, Utorok, ...)
# 9. %a – Skrátený názov dňa v týždni (Pon, Uto, ...)
# 10. %w – Deň v týždni (0-6, kde 0 je nedeľa)
# 11. %H – Hodina v 24-hodinovom formáte (00-23)
# 12. %I – Hodina v 12-hodinovom formáte (01-12)
# 13. %M – Minúty (00-59)
# 14. %S – Sekundy (00-59)
# 15. %p – AM alebo PM (len pre 12-hodinový formát)
# 16. %f – Mikrosekundy (6 číslic)
# 17. %z – Posun od UTC v časovom pásme (napr. +0200)
# 18. %Z – Názov časového pásma (napr. CET, UTC)
# 19. %X – Čas vo formáte (HH:MM:SS)
# 20. %D – Krátky dátum (MM/DD/YY)
# 21. %F – Dátum vo formáte YYYY-MM-DD
# 22. %T – Čas vo formáte HH:MM:SS

# %%
from datetime import datetime

datum = datetime.now()
# 19.03.2025 10:08:22
print(datum.strftime("%d.%m.%Y %H:%M:%S"))

# Rok-Mesiac-Deň (2025-03-18)
print(datum.strftime("%Y-%m-%d"))
        
# Deň/Mesiac/Rok (18/03/2025)
print(datum.strftime("%d/%m/%Y"))
        
# Názov mesiaca Deň, Rok (Marec 18, 2025)
print(datum.strftime("%B %d, %Y")) 
        
# Skrátený názov dňa, Deň Skrátený názov mesiaca Rok (Uto, 18 Mar 2025)        
print(datum.strftime("%a, %d %b %Y"))  
        
# Hodina:minúty AM/PM (03:45 PM)
print(datum.strftime("%I:%M %p"))

# Rok-Mesiac-Deň Hodina:Minúty:Sekundy (2025-03-18 15:45:30)
print(datum.strftime("%Y-%m-%d %H:%M:%S"))

# Názov dňa, Názov mesiaca Deň, Rok (Pondelok, Marec 18, 2025)
print(datum.strftime("%A, %B %d, %Y"))

# Hodina:Minúty:Sekundy (15:45:30)
print(datum.strftime("%H:%M:%S"))

# Dátum vo formáte YYYY-MM-DD (2025-03-18)
print(datum.strftime("%F"))

#  Čas vo formáte HH:MM:SS (15:45:30)
print(datum.strftime("%T"))
# Out:
# 18.03.2025 21:39:12
# 2025-03-18
# 18/03/2025
# March 18, 2025
# Tue, 18 Mar 2025
# 09:39 PM
# 2025-03-18 21:39:12
# Tuesday, March 18, 2025
# 21:39:12
# 2025-03-18
# 21:39:12

# %% [markdown]
# ## 🎲 Modul random – Generovanie náhodných hodnôt
# - Pozor pseudonáhodné čísla algoritmus mersennov twister
#
# https://docs.python.org/3/library/random.html
#
# 1. random.random() – Vygeneruje náhodné desatinné číslo v intervale [0.0, 1.0).
# 2. random.randint(a, b) – Vygeneruje náhodné celé číslo v intervale [a, b].
# 3. random.uniform(a, b) – Vygeneruje náhodné desatinné číslo v intervale [a, b].
# 4. random.choice(seq) – Vyberie náhodný prvok zo sekvencie (zoznam, reťazec, atď.).
# 5. random.choices(seq, weights=None, k=1) – Vyberie k náhodných prvkov zo sekvencie s možnosťou váh.
# 6. random.shuffle(lst) – Zmieša (náhodne premieša) prvky zoznamu lst.
# 7. random.sample(population, k) – Vyberie k unikátnych náhodných prvkov zo sekvencie alebo množiny.
# 8. random.seed(a=None) – Inicializuje generátor náhodných čísel s daným vzorkou.
# 9. random.triangular(low, high, mode) – Vygeneruje náhodné číslo podľa trojuholníkovej distribúcie medzi hodnotami low a high, s vrcholom v mode.
# 10. random.betavariate(alpha, beta) – Vygeneruje náhodné číslo z beta distribúcie.
# 11. random.gauss(mu, sigma) – Vygeneruje náhodné číslo z normálnej distribúcie (Gaussova distribúcia).
# 12. random.expovariate(lambd) – Vygeneruje náhodné číslo z exponenciálnej distribúcie.
# 13. random.paretovariate(alpha) – Vygeneruje náhodné číslo z Pareto distribúcie.
# 14. random.weibullvariate(alpha, beta) – Vygeneruje náhodné číslo z Weibullovej distribúcie.

# %% [markdown]
# 📌 Úloha: Generovať náhodné číslo od 1 do 10

# %%
import random
print(random.randint(1, 10))
# Out:
# 8

# %% [markdown]
# 📌 Úloha: Náhodne vybrať prvok zo zoznamu

# %%
import random

zoznam = ["Python", "Java", "C++", "Go"]
print(random.choice(zoznam))
# Out:
# Python

# %% [markdown]
# 📌 Úloha: Zmiešať prvky zoznamu

# %%
import random

# Pôvodný zoznam
zoznam = [1, 2, 3, 4, 5]

# Zmieša zoznam
random.shuffle(zoznam)

# Výstup: zmiešaný zoznam
print(zoznam)
# Out:
# [3, 1, 5, 4, 2]

# %% [markdown]
# 📌 Úloha: Vybrať náhodných k prvkov zo sekvencie

# %%
import random

# Pôvodný zoznam
zoznam = [1, 2, 3, 4, 5]

# Vyberieme 3 náhodné prvky zo zoznamu
vzorovy_vyber = random.sample(zoznam, 3)

# Výstup: náhodný výber 3 prvkov
print(vzorovy_vyber)
# Out:
# [1, 5, 4]

# %% [markdown]
# 📌 Úloha: Inicializovať generátor náhodných čísel so zadanou vzorkou
#
# - Seed je počiatočná hodnota, ktorá sa používa na inicializáciu generátora náhodných čísel, aby sa generovali sekvencie čísel, ktoré sú opakovateľné.
#
# - Keď nastavíte semeno na rovnakú hodnotu (napr. random.seed(10)), generátor náhodných čísel začne vždy s rovnakým počiatočným stavom. Tento stav určuje, ako sa následne vygenerujú náhodné čísla. Ak použijete rovnaký seed a rovnaké operácie na generovanie náhodných čísel, výsledky budú vždy rovnaké.
#
# - V praxi to znamená, že ak použijete random.seed(10) pred volaním random.random(), vždy dostanete rovnaké číslo, pretože generátor náhodných čísel vždy začína s rovnakým počiatočným stavom.

# %%
import random

# Nastavíme semeno na hodnotu 10
random.seed(10)

# Vygenerujeme náhodné číslo
print(random.random())  # Výstup bude rovnaký vždy pri rovnakej vzorke
# Out:
# 0.5714025946899135

# %% [markdown]
# 📌 Úloha: Vygenerovať náhodné číslo z normálnej distribúcie (Gaussova distribúcia)

# %%
import random

# Vygenerujeme náhodné číslo z normálnej distribúcie s priemerom 0 a smerodajnou odchýlkou 1
gauss_nahodne_cislo = random.gauss(0, 1)

print(gauss_nahodne_cislo)
# Out:
# 0.8054966422852629

# %%
import random
import matplotlib.pyplot as plt

# Generujeme 1000 náhodných čísel z normálnej distribúcie s priemerom 0 a smerodajnou odchýlkou 1
gauss_values = [random.gauss(0, 1) for _ in range(1000)]

# Vytvoríme histogram pre vizualizáciu rozdelenia
plt.hist(gauss_values, bins=30, edgecolor='black', alpha=0.7)
plt.title('Normálne rozdelenie (Gaussova distribúcia)')
plt.xlabel('Hodnota')
plt.ylabel('Frekvencia')
plt.grid(True)
plt.show()

# %% [markdown]
# # Collections

# %% [markdown]
# # 📦 Efektívna práca s dátovými štruktúrami
# collections – Pokročilé dátové štruktúry
#
# 1. namedtuple() – vytvára nové typy n-tíc s pomenovanými poľami
# 2. deque – umožňuje rýchle pridávanie a odoberanie prvkov z oboch koncov dvojitej fronty
# 3. Counter() – počíta počet výskytov jednotlivých položiek v iterable
# 4. OrderedDict() – slovník, ktorý zachováva poradie vloženia kľúčov
# 5. defaultdict() – slovník, ktorý automaticky inicializuje hodnotu pre neexistujúce kľúče
# 6. ChainMap() – kombinuje viacero slovníkov do jedného a postupne kontroluje ich obsah
# 7. UserDict – umožňuje vytvárať vlastné implementácie slovníkov s prispôsobeným správaním
# 8. Mapping – abstraktná základná trieda pre prispôsobenie správania slovníkov
# 9. KeysView – zobrazuje kľúče v slovníku
# 10. ItemsView – zobrazuje položky (kľúč, hodnota) v slovníku

# %% [markdown]
# 📌 Úloha: Použitie namedtuple

# %%
from collections import namedtuple

# Vytvorenie namedtuple pre bod
Point = namedtuple('Point', ['x', 'y'])

# Vytvorenie inštancie namedtuple
p = Point(10, 20)

# Zobrazenie hodnôt
print(p)
# Výstup: Point(x=10, y=20)

# Prístup k hodnotám pomocou pomenovaných polí
print(p.x)  # Výstup: 10
print(p.y)  # Výstup: 20
# Out:
# Point(x=10, y=20)
# 10
# 20

# %% [markdown]
# 📌 Úloha: Použitie ChainMap

# %%
from collections import ChainMap

# Vytvorenie dvoch slovníkov
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

# Kombinovanie slovníkov do ChainMap
chain_map = ChainMap(dict1, dict2)

# Zobrazenie ChainMap
print(chain_map)
# Výstup: ChainMap({'a': 1, 'b': 2}, {'b': 3, 'c': 4})

# Prístup k hodnotám (pozor, ChainMap prioritizuje prvý slovník)
print(chain_map['b'])  # Výstup: 2 (z dict1, pretože je na prvom mieste)
print(chain_map['c'])  # Výstup: 4 (z dict2)
# Out:
# ChainMap({'a': 1, 'b': 2}, {'b': 3, 'c': 4})
# 2
# 4

# %% [markdown]
# 📌 Úloha: Použitie Counter na spočítanie prvkov v zozname

# %%
from collections import Counter
zoznam = ["a", "b", "a", "c", "b", "a"]
print(Counter(zoznam))  # {'a': 3, 'b': 2, 'c': 1}
# Out:
# Counter({'a': 3, 'b': 2, 'c': 1})

# %% [markdown]
# 📌 Úloha: Použitie OrderedDict

# %%
from collections import OrderedDict

# Vytvorenie OrderedDict s pridaním položiek
ordered_dict = OrderedDict()
ordered_dict['a'] = 1
ordered_dict['b'] = 2
ordered_dict['c'] = 3
ordered_dict['d'] = 4
ordered_dict['e'] = 5

# Zobrazenie OrderedDict
print(ordered_dict)
# Výstup: OrderedDict([('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5)])

# Zmena poradia kľúčov
ordered_dict.move_to_end('b')
print(ordered_dict)
# Výstup: OrderedDict([('a', 1), ('c', 3), ('d', 4), ('e', 5), ('b', 2)])
# Out:
# OrderedDict([('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5)])
# OrderedDict([('a', 1), ('c', 3), ('d', 4), ('e', 5), ('b', 2)])

# %% [markdown]
# 📌 Úloha: Použitie UserDict

# %%
from collections import UserDict

# Vytvorenie vlastného slovníka pomocou UserDict
class CustomDict(UserDict):
    def __setitem__(self, key, value):
        print(f"Pridávam {key}: {value}")
        super().__setitem__(key, value)

# Použitie CustomDict
custom_dict = CustomDict()
custom_dict['x'] = 10
custom_dict['y'] = 20
print(custom_dict)
# Výstup:
# Pridávam x: 10
# Pridávam y: 20
# {'x': 10, 'y': 20}
# Out:
# Pridávam x: 10
# Pridávam y: 20
# {'x': 10, 'y': 20}

# %% [markdown]
# 📌 Úloha: Použitie defaultdict na automatické vytváranie hodnôt

# %%
from collections import defaultdict
dd = defaultdict(int)
dd["a"] += 1
print(dd)  # {'a': 1}
# Out:
# defaultdict(<class 'int'>, {'a': 1})

# %% [markdown]
# 📌 Úloha: Použitie deque na efektívne pridávanie a odoberanie prvkov

# %%
from collections import deque
q = deque([1, 2, 3])
q.appendleft(0)
q.append(4)
print(q)  # deque([0, 1, 2, 3, 4])
# Out:
# deque([0, 1, 2, 3, 4])

# %% [markdown]
# # Logovanie a Diagnostika

# %% [markdown]
# # 📝 Logovanie a diagnostika
# - logging – Zaznamenávanie udalostí a logy
# - sys – Informácie o systéme

# %% [markdown]
# ## 📝 logging – Zaznamenávanie udalostí a logy
#
# 1. logging.basicConfig() – Nastaví základnú konfiguráciu logovania (úroveň logovania, formát, výstup).
# 2. logging.debug() – Vytvorí log správu s úrovňou DEBUG (pre vývojové účely).
# 3. logging.info() – Vytvorí log správu s úrovňou INFO (pre bežné informácie).
# 4. logging.warning() – Vytvorí log správu s úrovňou WARNING (pre varovania).
# 5. logging.error() – Vytvorí log správu s úrovňou ERROR (pre chyby).
# 6. logging.critical() – Vytvorí log správu s úrovňou CRITICAL (pre kritické chyby).
# 7. logging.exception() – Vytvorí log správu s úrovňou ERROR a automaticky pridá traceback výnimky.
# 8. logging.log() – Vytvorí log správu so špecifikovanou úrovňou logovania (môže byť užitočné pre dynamické nastavenie úrovne).
# 9. logging.getLogger() – Získa alebo vytvorí inštanciu loggera, ktorá je použiteľná na logovanie správ.
# 10. logging.shutdown() – Uvoľní všetky zdroje a zavrie všetky otvorené log súbory.

# %% [markdown]
# 📌 Úloha: Základné logovanie

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Toto je informačná správa.")
# Out:
# INFO:root:Toto je informačná správa.

# %%
# Ako sa zaznamená varovanie v prípade, keď hodnota premennej nevyhovuje očakávaniam:
import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Funkcia, ktorá kontroluje vek osoby
def check_age(age):
    if age < 18:
        logging.warning("Vek osoby je nižší ako 18 rokov: %d", age)
    else:
        print("Vek je v poriadku.")

# Testovanie
check_age(16)
check_age(20)
# Out:
# Vek je v poriadku.
# 2025-03-18 22:09:45,290 - WARNING - Vek osoby je nižší ako 18 rokov: 16

# %%
# Ako sa zaznamená chyba v prípade, že program narazí na neplatný vstup
import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Funkcia, ktorá robí delenie
def divide_numbers(a, b):
    try:
        result = a / b
        print(f"Výsledok delenia: {result}")
    except ZeroDivisionError:
        logging.error("Pokúsili ste sa deliť nulou!")
        
# Testovanie
divide_numbers(10, 2)
divide_numbers(10, 0)
# Out:
# Výsledok delenia: 5.0
# 2025-03-18 22:10:27,962 - ERROR - Pokúsili ste sa deliť nulou!

# %% [markdown]
# 📌 Úloha: Logovanie do súboru

# %%
logging.basicConfig(filename="app.log", level=logging.DEBUG)
logging.debug("Toto je debuggovacia správa.")
# Out:
# 2025-03-18 22:10:37,711 - DEBUG - Toto je debuggovacia správa.

# %%
# Ako sa používa getLogger() na získanie loggera a nastavenie rôznych úrovní logovania pre rôzne logger objekty:

import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Získanie loggera s názvom 'app_logger'
logger = logging.getLogger('app_logger')

# Logger s úrovňou INFO
logger.setLevel(logging.INFO)

# Logovanie správ
logger.debug("Toto je správa na úrovni DEBUG")  # Táto správa nebude zobrazená
logger.info("Toto je správa na úrovni INFO")  # Táto správa bude zobrazená
logger.warning("Toto je správa na úrovni WARNING")  # Táto správa bude zobrazená
# Out:
# 2025-03-18 22:11:31,955 - INFO - Toto je správa na úrovni INFO
# 2025-03-18 22:11:31,958 - WARNING - Toto je správa na úrovni WARNING

# %%
# Ako sa používa logging.shutdown() na bezpečné uzavretie a uvoľnenie všetkých zdrojov, ktoré sa používajú pri logovaní:

import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Vytvorenie logovacej správy
logging.info("Toto je log správa pred ukončením.")

# Zastavenie logovania (ukončenie všetkých logovacích procesov a uzavretie súborov)
logging.shutdown()

# Ak sa pokúsite logovať po zavolaní shutdown, vyvolá to výnimku
try:
    logging.info("Toto nebude logované.")
except ValueError as e:
    print("Chyba:", e)
# Out:
# 2025-03-18 22:12:25,471 - INFO - Toto je log správa pred ukončením.
# 2025-03-18 22:12:25,476 - INFO - Toto nebude logované.

# %%
# Uloženie logov do súboru

import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.FileHandler('logfile.log'),  # Ukladá logy do súboru 'logfile.log'
    logging.StreamHandler()  # Taktiež zobrazuje logy na konzole
])

# Logovanie rôznych úrovní správ
logging.debug("Toto je správa na úrovni DEBUG")
logging.info("Toto je správa na úrovni INFO")
logging.warning("Toto je správa na úrovni WARNING")
logging.error("Toto je správa na úrovni ERROR")
logging.critical("Toto je správa na úrovni CRITICAL")

# Zavretie logovania a uvoľnenie prostriedkov
logging.shutdown()

# Súbor 'logfile.log' je teraz uzavretý a všetky logy sú správne zaznamenané
# Out:
# 2025-03-18 22:18:33,120 - DEBUG - Toto je správa na úrovni DEBUG
# 2025-03-18 22:18:33,125 - INFO - Toto je správa na úrovni INFO
# 2025-03-18 22:18:33,127 - WARNING - Toto je správa na úrovni WARNING
# 2025-03-18 22:18:33,129 - ERROR - Toto je správa na úrovni ERROR
# 2025-03-18 22:18:33,134 - CRITICAL - Toto je správa na úrovni CRITICAL

# %%
import logging

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(
    level=logging.DEBUG,  # Nastavenie najnižšej úrovne logovania
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.FileHandler('logfile.log', mode='w')]  # Použitie zápisu do súboru
)

# Logovanie rôznych úrovní správ
logging.debug("Toto je správa na úrovni DEBUG")
logging.info("Toto je správa na úrovni INFO")
logging.warning("Toto je správa na úrovni WARNING")
logging.error("Toto je správa na úrovni ERROR")
logging.critical("Toto je správa na úrovni CRITICAL")

# Zavretie logovania a uvoľnenie prostriedkov
logging.shutdown()

# Súbor 'logfile.log' je teraz uzavretý a všetky logy sú správne zaznamenané

# %%
# Čítanie logov zo súboru
from importlib import reload
reload(logging)

# Otvorenie súboru a čítanie logov
with open('logfile.log', 'r') as file:
    log_content = file.read()

# Vytlačenie obsahu log súboru
print(log_content)
# Out:
# 2025-03-18 22:26:14,028 - DEBUG - Toto je správa na úrovni DEBUG
# 2025-03-18 22:26:14,029 - INFO - Toto je správa na úrovni INFO
# 2025-03-18 22:26:14,029 - WARNING - Toto je správa na úrovni WARNING
# 2025-03-18 22:26:14,029 - ERROR - Toto je správa na úrovni ERROR
# 2025-03-18 22:26:14,030 - CRITICAL - Toto je správa na úrovni CRITICAL

# %%
# Príklad s logovaním do súboru v Jupyter notebooku
import logging
from importlib import reload
reload(logging)

# Nastavenie základnej konfigurácie logovania
logging.basicConfig(
    level=logging.DEBUG,  # Nastavenie úrovne na DEBUG
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('logfile3.log', mode='w'),  # Ukladá logy do súboru 'logfile.log'
        logging.StreamHandler()  # Zobrazuje logy na konzole
    ]
)

# Logovanie rôznych úrovní správ
logging.debug("Toto je správa na úrovni DEBUG")
logging.info("Toto je správa na úrovni INFO")
logging.warning("Toto je správa na úrovni WARNING")
logging.error("Toto je správa na úrovni ERROR")
logging.critical("Toto je správa na úrovni CRITICAL")

# Zavretie logovania a uvoľnenie prostriedkov
logging.shutdown()

# Skontrolovanie obsahu log súboru
with open('logfile3.log', 'r') as file:
    print(file.read())  # Zobrazenie obsahu log súboru
# Out:
# 2025-03-18 22:25:15,613 - DEBUG - Toto je správa na úrovni DEBUG
# 2025-03-18 22:25:15,615 - INFO - Toto je správa na úrovni INFO
# 2025-03-18 22:25:15,617 - WARNING - Toto je správa na úrovni WARNING
# 2025-03-18 22:25:15,619 - ERROR - Toto je správa na úrovni ERROR
# 2025-03-18 22:25:15,621 - CRITICAL - Toto je správa na úrovni CRITICAL
# 2025-03-18 22:25:15,613 - DEBUG - Toto je správa na úrovni DEBUG
# 2025-03-18 22:25:15,615 - INFO - Toto je správa na úrovni INFO
# 2025-03-18 22:25:15,617 - WARNING - Toto je správa na úrovni WARNING
# 2025-03-18 22:25:15,619 - ERROR - Toto je správa na úrovni ERROR
# 2025-03-18 22:25:15,621 - CRITICAL - Toto je správa na úrovni CRITICAL

# %% [markdown]
# ## ⚙️ sys – Informácie o systéme
#
# 1. sys.argv – Zoznam argumentov príkazového riadku.
# 2. sys.exit([status]) – Ukončí program s voliteľným stavovým kódom.
# 3. sys.version – Vracia reťazec s informáciami o verzii Pythonu.
# 4. sys.path – Zoznam adresárov, kde Python hľadá moduly.
# 5. sys.platform – Zisťuje platformu (napr. 'linux', 'win32').
# 6. sys.getsizeof(object) – Získava veľkosť objektu v bajtoch.
# 7. sys.setrecursionlimit(limit) – Nastavuje limit pre počet rekurzívnych volaní.
# 8. sys.stdin, sys.stdout, sys.stderr – Získava prístup k vstupu, výstupu a chybovému výstupu.
# 9. sys.modules – Zoznam nahraných modulov v aktuálnom prostredí.
# 10. sys.getrefcount(object) – Zisťuje počet odkazov na daný objekt.

# %% [markdown]
# 📌 Úloha: Zobraziť verziu Pythonu

# %%
import sys
print(sys.version)
# Out:
# 3.8.20 (default, Mar  4 2025, 17:24:18)
# [GCC 11.4.0]

# %%
# zoznam adresárov, ktoré Python používa na hľadanie modulov.

import sys

# Zobraziť všetky adresáre, kde Python hľadá moduly
print("Zoznam adresárov v sys.path:")
for path in sys.path:
    print(path)
# Out:
# Zoznam adresárov v sys.path:
# /data/notebook_files
# /opt/datalore/python
# /var/datalore/manager/.pip
# /data/workspace_files
# /opt/python/lib/python38.zip
# /opt/python/lib/python3.8
# /opt/python/lib/python3.8/lib-dynload
#
# /opt/python/envs/default/lib/python3.8/site-packages
# /opt/python/envs/default/lib/python3.8/site-packages/IPython/extensions
# /opt/python/envs/default/lib/python3.8/site-packages/setuptools/_vendor
# /home/datalore/.ipython

# %%
# Aká platforma je aktuálne používaná.
import sys

# Zobraziť platformu, na ktorej Python beží
print(f"Platforma, na ktorej beží Python: {sys.platform}")
# Out:
# Platforma, na ktorej beží Python: linux

# %%
# Ako zistiť veľkosť objektu v pamäti v bajtoch.

import sys

# Vytvorenie rôznych objektov
text = "Hello, World!"
cislo = 123
zoznam = [1, 2, 3, 4, 5]

# Zobraziť veľkosti objektov v bajtoch
print(f"Veľkosť textu: {sys.getsizeof(text)} bajtov")
print(f"Veľkosť čísla: {sys.getsizeof(cislo)} bajtov")
print(f"Veľkosť zoznamu: {sys.getsizeof(zoznam)} bajtov")
# Out:
# Veľkosť textu: 62 bajtov
# Veľkosť čísla: 28 bajtov
# Veľkosť zoznamu: 96 bajtov

# %%
# Ako získať zoznam všetkých nahraných modulov v aktuálnom Python prostredí.

import sys

# Zobraziť zoznam všetkých nahraných modulov
print("Nahrané moduly:")
for mod in sys.modules:
    print(mod)
# Out:
# Nahrané moduly:
# sys
# builtins
# _frozen_importlib
# _imp
# _warnings
# _io
# marshal
# posix
# _frozen_importlib_external
# _thread
# _weakref
# time
# zipimport
# _codecs
# codecs
# encodings.aliases
# encodings
# encodings.utf_8
# _signal
# __main__
# encodings.latin_1
# _abc
# abc
# io
# _stat
# stat
# _collections_abc
# genericpath
# posixpath
# os.path
# os
# _sitebuiltins
# _locale
# _bootlocale
# _distutils_hack
# types
# importlib._bootstrap
# importlib._bootstrap_external
# warnings
# importlib
# importlib.machinery
# importlib.abc
# _operator
# operator
# keyword
# _heapq
# heapq
# itertools
# reprlib
# _collections
# collections
# _functools
# functools
# contextlib
# importlib.util
# mpl_toolkits
# google
# sphinxcontrib
# site
# _weakrefset
# weakref
# pkgutil
# runpy
# ipykernel._version
# enum
# _sre
# sre_constants
# sre_parse
# sre_compile
# copyreg
# re
# _json
# json.scanner
# json.decoder
# json.encoder
# json
# errno
# signal
# threading
# _posixsubprocess
# ...
